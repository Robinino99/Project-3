# %% [markdown]
# # Project (Part 2)_B

# %%
import pandas as pd


pd.set_option('display.max_columns', None)

# %%
# import both gz files and then combine them
df_2000 = pd.read_csv(r"C:\Users\om22285\OneDrive - Old Mutual\Documents\Employee Performance\2023\Umluzi Data Science Bootcamp\Coding Dojo Environment\Project-3\Data\Moviesfinal_tmdb_data_2000.csv.gz")
df_2001 = pd.read_csv(r"C:\Users\om22285\OneDrive - Old Mutual\Documents\Employee Performance\2023\Umluzi Data Science Bootcamp\Coding Dojo Environment\Project-3\Data\Moviesfinal_tmdb_data_2001.csv.gz")

# %%
# combine dataframes into one
df_combined = pd.concat([df_2000, df_2001], axis=0)
df_combined.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
#          id original_language   original_title  \
# ...

# %%
# Number of movies per certification
df_combined.groupby('certification').count()
# Out:
#                imdb_id  adult  backdrop_path  belongs_to_collection  budget  \
# certification
# G                   74     74             54                     20      74
# NC-17              187    187             30                     14     187
# NR                 181    181             67                      8     181
# PG                  95     95             69                     18      95
# PG-13              215    215            184                     32     215
# R                  506    506            395                     70     506
# Unrated              1      1              1                      0       1
# X                    1      1              0                      0       1
#
#                genres  homepage   id  original_language  original_title  \
# certification
# G                  74         7   74                 74              74
# NC-17             187         2  187                187             187
# ...

# %%
# Average revenue per category
df_combined.groupby('certification')['revenue'].mean().round()
# Out:
# certification
# G          23445917.28
# NC-17             0.00
# NR          1842888.04
# PG         40458304.35
# PG-13      60504699.97
# R          13274799.90
# Unrated           0.00
# X                 0.00
# Name: revenue, dtype: float64

# %%
# Average budget per category
df_combined.groupby('certification')['budget'].mean().round(2)
# Out:
# certification
# G           7731046.81
# NC-17            64.17
# NR          1008273.17
# PG         16244736.88
# PG-13      26645871.57
# R           8257806.40
# Unrated           0.00
# X                 0.00
# Name: budget, dtype: float64
